# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/taylor_swift_02.jpg')
img.shape
# Out:
# (1000, 1500, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1000, 1500)

# %%
gray
# Out:
# array([[164, 164, 164, ...,  15,  15,  15],
#        [164, 164, 164, ...,  17,  17,  17],
#        [164, 164, 164, ...,  19,  19,  19],
#        ...,
#        [175, 175, 175, ...,  16,  16,  16],
#        [175, 175, 175, ...,  16,  16,  16],
#        [175, 175, 175, ...,  16,  16,  16]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[552, 129, 380, 380]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (552, 129, 380, 380)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (380, 380, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/taylor_swift_02.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/taylor_swift_02.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images/taylor_01.jpg')
plt.imshow(org_image_obstructed)

# %%
org_image_obstructed = cv2.imread('./test_images/taylor_swift_001.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/taylor_swift_001.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/justin_bieber',
#  './dataset/Katy_Perry',
#  './dataset/Michael_Jackson',
#  './dataset/selena_gomez',
#  './dataset/taylor_swift']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/justin_bieber
# Generating cropped images in folder:  ./dataset/cropped/Katy_Perry
# Generating cropped images in folder:  ./dataset/cropped/Michael_Jackson
# Generating cropped images in folder:  ./dataset/cropped/selena_gomez
# Generating cropped images in folder:  ./dataset/cropped/taylor_swift

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'justin_bieber': ['./dataset/cropped/justin_bieber\\justin_bieber1.png',
#   './dataset/cropped/justin_bieber\\justin_bieber10.png',
#   './dataset/cropped/justin_bieber\\justin_bieber11.png',
#   './dataset/cropped/justin_bieber\\justin_bieber12.png',
#   './dataset/cropped/justin_bieber\\justin_bieber13.png',
#   './dataset/cropped/justin_bieber\\justin_bieber14.png',
#   './dataset/cropped/justin_bieber\\justin_bieber15.png',
#   './dataset/cropped/justin_bieber\\justin_bieber16.png',
#   './dataset/cropped/justin_bieber\\justin_bieber17.png',
#   './dataset/cropped/justin_bieber\\justin_bieber18.png',
#   './dataset/cropped/justin_bieber\\justin_bieber19.png',
#   './dataset/cropped/justin_bieber\\justin_bieber2.png',
#   './dataset/cropped/justin_bieber\\justin_bieber20.png',
#   './dataset/cropped/justin_bieber\\justin_bieber21.png',
#   './dataset/cropped/justin_bieber\\justin_bieber22.png',
#   './dataset/cropped/justin_bieber\\justin_bieber23.png',
#   './dataset/cropped/justin_bieber\\justin_bieber24.png',
#   './dataset/cropped/justin_bieber\\justin_bieber25.png',
#   './dataset/cropped/justin_bieber\\justin_bieber26.png',
#   './dataset/cropped/justin_bieber\\justin_bieber27.png',
#   './dataset/cropped/justin_bieber\\justin_bieber28.png',
#   './dataset/cropped/justin_bieber\\justin_bieber29.png',
#   './dataset/cropped/justin_bieber\\justin_bieber3.png',
#   './dataset/cropped/justin_bieber\\justin_bieber30.png',
#   './dataset/cropped/justin_bieber\\justin_bieber31.png',
#   './dataset/cropped/justin_bieber\\justin_bieber4.png',
#   './dataset/cropped/justin_bieber\\justin_bieber5.png',
#   './dataset/cropped/justin_bieber\\justin_bieber6.png',
#   './dataset/cropped/justin_bieber\\justin_bieber7.png',
#   './dataset/cropped/justin_bieber\\justin_bieber8.png',
#   './dataset/cropped/justin_bieber\\justin_bieber9.png'],
#  'Katy_Perry': ['./dataset/cropped/Katy_Perry\\Katy_Perry1.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry10.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry11.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry12.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry13.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry14.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry15.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry16.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry17.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry18.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry19.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry2.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry20.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry21.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry22.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry23.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry24.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry25.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry26.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry27.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry28.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry29.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry3.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry30.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry31.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry32.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry33.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry34.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry35.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry36.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry37.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry38.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry39.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry4.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry40.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry41.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry42.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry43.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry44.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry45.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry5.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry6.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry7.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry8.png',
#   './dataset/cropped/Katy_Perry\\Katy_Perry9.png'],
#  'Michael_Jackson': ['./dataset/cropped/Michael_Jackson\\Michael_Jackson1.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson10.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson11.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson12.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson13.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson14.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson15.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson16.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson17.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson18.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson19.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson2.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson20.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson21.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson23.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson24.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson25.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson26.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson27.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson28.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson29.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson3.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson30.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson31.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson32.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson33.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson34.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson35.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson36.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson37.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson38.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson39.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson4.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson40.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson41.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson42.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson43.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson44.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson45.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson46.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson47.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson48.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson49.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson5.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson50.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson51.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson52.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson53.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson54.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson55.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson56.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson57.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson58.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson59.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson6.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson60.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson61.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson62.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson63.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson64.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson65.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson66.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson67.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson69.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson7.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson8.png',
#   './dataset/cropped/Michael_Jackson\\Michael_Jackson9.png'],
#  'selena_gomez': ['./dataset/cropped/selena_gomez\\selena_gomez1.png',
#   './dataset/cropped/selena_gomez\\selena_gomez10.png',
#   './dataset/cropped/selena_gomez\\selena_gomez11.png',
#   './dataset/cropped/selena_gomez\\selena_gomez12.png',
#   './dataset/cropped/selena_gomez\\selena_gomez13.png',
#   './dataset/cropped/selena_gomez\\selena_gomez14.png',
#   './dataset/cropped/selena_gomez\\selena_gomez15.png',
#   './dataset/cropped/selena_gomez\\selena_gomez16.png',
#   './dataset/cropped/selena_gomez\\selena_gomez17.png',
#   './dataset/cropped/selena_gomez\\selena_gomez18.png',
#   './dataset/cropped/selena_gomez\\selena_gomez19.png',
#   './dataset/cropped/selena_gomez\\selena_gomez2.png',
#   './dataset/cropped/selena_gomez\\selena_gomez20.png',
#   './dataset/cropped/selena_gomez\\selena_gomez21.png',
#   './dataset/cropped/selena_gomez\\selena_gomez22.png',
#   './dataset/cropped/selena_gomez\\selena_gomez23.png',
#   './dataset/cropped/selena_gomez\\selena_gomez24.png',
#   './dataset/cropped/selena_gomez\\selena_gomez25.png',
#   './dataset/cropped/selena_gomez\\selena_gomez26.png',
#   './dataset/cropped/selena_gomez\\selena_gomez27.png',
#   './dataset/cropped/selena_gomez\\selena_gomez28.png',
#   './dataset/cropped/selena_gomez\\selena_gomez29.png',
#   './dataset/cropped/selena_gomez\\selena_gomez3.png',
#   './dataset/cropped/selena_gomez\\selena_gomez30.png',
#   './dataset/cropped/selena_gomez\\selena_gomez31.png',
#   './dataset/cropped/selena_gomez\\selena_gomez32.png',
#   './dataset/cropped/selena_gomez\\selena_gomez33.png',
#   './dataset/cropped/selena_gomez\\selena_gomez34.png',
#   './dataset/cropped/selena_gomez\\selena_gomez35.png',
#   './dataset/cropped/selena_gomez\\selena_gomez36.png',
#   './dataset/cropped/selena_gomez\\selena_gomez37.png',
#   './dataset/cropped/selena_gomez\\selena_gomez38.png',
#   './dataset/cropped/selena_gomez\\selena_gomez39.png',
#   './dataset/cropped/selena_gomez\\selena_gomez4.png',
#   './dataset/cropped/selena_gomez\\selena_gomez40.png',
#   './dataset/cropped/selena_gomez\\selena_gomez41.png',
#   './dataset/cropped/selena_gomez\\selena_gomez42.png',
#   './dataset/cropped/selena_gomez\\selena_gomez43.png',
#   './dataset/cropped/selena_gomez\\selena_gomez44.png',
#   './dataset/cropped/selena_gomez\\selena_gomez45.png',
#   './dataset/cropped/selena_gomez\\selena_gomez46.png',
#   './dataset/cropped/selena_gomez\\selena_gomez47.png',
#   './dataset/cropped/selena_gomez\\selena_gomez48.png',
#   './dataset/cropped/selena_gomez\\selena_gomez49.png',
#   './dataset/cropped/selena_gomez\\selena_gomez5.png',
#   './dataset/cropped/selena_gomez\\selena_gomez50.png',
#   './dataset/cropped/selena_gomez\\selena_gomez51.png',
#   './dataset/cropped/selena_gomez\\selena_gomez52.png',
#   './dataset/cropped/selena_gomez\\selena_gomez53.png',
#   './dataset/cropped/selena_gomez\\selena_gomez54.png',
#   './dataset/cropped/selena_gomez\\selena_gomez55.png',
#   './dataset/cropped/selena_gomez\\selena_gomez56.png',
#   './dataset/cropped/selena_gomez\\selena_gomez57.png',
#   './dataset/cropped/selena_gomez\\selena_gomez58.png',
#   './dataset/cropped/selena_gomez\\selena_gomez59.png',
#   './dataset/cropped/selena_gomez\\selena_gomez6.png',
#   './dataset/cropped/selena_gomez\\selena_gomez60.png',
#   './dataset/cropped/selena_gomez\\selena_gomez61.png',
#   './dataset/cropped/selena_gomez\\selena_gomez62.png',
#   './dataset/cropped/selena_gomez\\selena_gomez63.png',
#   './dataset/cropped/selena_gomez\\selena_gomez64.png',
#   './dataset/cropped/selena_gomez\\selena_gomez65.png',
#   './dataset/cropped/selena_gomez\\selena_gomez66.png',
#   './dataset/cropped/selena_gomez\\selena_gomez7.png',
#   './dataset/cropped/selena_gomez\\selena_gomez8.png',
#   './dataset/cropped/selena_gomez\\selena_gomez9.png'],
#  'taylor_swift': ['./dataset/cropped/taylor_swift\\taylor_swift1.png',
#   './dataset/cropped/taylor_swift\\taylor_swift10.png',
#   './dataset/cropped/taylor_swift\\taylor_swift11.png',
#   './dataset/cropped/taylor_swift\\taylor_swift12.png',
#   './dataset/cropped/taylor_swift\\taylor_swift13.png',
#   './dataset/cropped/taylor_swift\\taylor_swift14.png',
#   './dataset/cropped/taylor_swift\\taylor_swift15.png',
#   './dataset/cropped/taylor_swift\\taylor_swift2.png',
#   './dataset/cropped/taylor_swift\\taylor_swift3.png',
#   './dataset/cropped/taylor_swift\\taylor_swift4.png',
#   './dataset/cropped/taylor_swift\\taylor_swift5.png',
#   './dataset/cropped/taylor_swift\\taylor_swift6.png',
#   './dataset/cropped/taylor_swift\\taylor_swift7.png',
#   './dataset/cropped/taylor_swift\\taylor_swift8.png',
#   './dataset/cropped/taylor_swift\\taylor_swift9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'justin_bieber': 0,
#  'Katy_Perry': 1,
#  'Michael_Jackson': 2,
#  'selena_gomez': 3,
#  'taylor_swift': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 78],
#        [122],
#        [177],
#        ...,
#        [118],
#        [103],
#        [ 89]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (224, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6964285714285714

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.43      0.50         7
#            1       0.62      0.62      0.62         8
#            2       0.60      0.83      0.70        18
#            3       0.88      0.68      0.77        22
#            4       1.00      1.00      1.00         1
#
#     accuracy                           0.70        56
#    macro avg       0.74      0.71      0.72        56
# weighted avg       0.72      0.70      0.70        56

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.672193
# 1        random_forest    0.457932
# 2  logistic_regression    0.583066
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.75

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5714285714285714

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7142857142857143

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  0,  2,  0,  0],
#        [ 1,  6,  0,  1,  0],
#        [ 1,  1, 14,  2,  0],
#        [ 1,  2,  3, 16,  0],
#        [ 0,  0,  0,  0,  1]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'justin_bieber': 0,
#  'Katy_Perry': 1,
#  'Michael_Jackson': 2,
#  'selena_gomez': 3,
#  'taylor_swift': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
